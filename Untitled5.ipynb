# %%
pip install jupyter_plotly_dash
# Out:
# Collecting jupyter_plotly_dash
#   Downloading jupyter_plotly_dash-0.4.3-py3-none-any.whl (29 kB)
# Collecting dpd-static-support
#   Downloading dpd_static_support-0.0.5-py3-none-any.whl (509 kB)
#      ------------------------------------ 509.6/509.6 kB 492.0 kB/s eta 0:00:00
# Collecting dpd-components
#   Downloading dpd_components-0.1.0.tar.gz (4.3 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-win_amd64.whl (323 kB)
#      -------------------------------------- 323.6/323.6 kB 2.0 MB/s eta 0:00:00
# Collecting django-plotly-dash
#   Downloading django_plotly_dash-2.1.4-py3-none-any.whl (55 kB)
#      ---------------------------------------- 55.2/55.2 kB 2.8 MB/s eta 0:00:00
# Collecting django-bootstrap4
#   Downloading django_bootstrap4-22.3-py3-none-any.whl (24 kB)
# Collecting nbserverproxy
#   Downloading nbserverproxy-0.8.8-py3-none-any.whl (7.5 kB)
# Requirement already satisfied: jupyter in c:\users\user\anaconda3\lib\site-packages (from jupyter_plotly_dash) (1.0.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-win_amd64.whl (28 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp->jupyter_plotly_dash) (21.4.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-win_amd64.whl (56 kB)
#      ---------------------------------------- 56.8/56.8 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp->jupyter_plotly_dash) (2.0.4)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-win_amd64.whl (34 kB)
# Requirement already satisfied: beautifulsoup4>=4.8.0 in c:\users\user\anaconda3\lib\site-packages (from django-bootstrap4->jupyter_plotly_dash) (4.11.1)
# Collecting Django>=3.2
#   Downloading Django-4.2-py3-none-any.whl (8.0 MB)
#      ---------------------------------------- 8.0/8.0 MB 2.7 MB/s eta 0:00:00
# Collecting dash-bootstrap-components
#   Downloading dash_bootstrap_components-1.4.1-py3-none-any.whl (220 kB)
#      -------------------------------------- 220.6/220.6 kB 6.8 MB/s eta 0:00:00
# Collecting channels>=2.0
#   Downloading channels-4.0.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: Werkzeug in c:\users\user\anaconda3\lib\site-packages (from django-plotly-dash->jupyter_plotly_dash) (2.0.3)
# Collecting Django>=3.2
#   Downloading Django-3.2.18-py3-none-any.whl (7.9 MB)
#      ---------------------------------------- 7.9/7.9 MB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: dash>=2.0 in c:\users\user\anaconda3\lib\site-packages (from django-plotly-dash->jupyter_plotly_dash) (2.9.2)
# Requirement already satisfied: Flask>=1.0.2 in c:\users\user\anaconda3\lib\site-packages (from django-plotly-dash->jupyter_plotly_dash) (1.1.2)
# Requirement already satisfied: plotly in c:\users\user\anaconda3\lib\site-packages (from django-plotly-dash->jupyter_plotly_dash) (5.9.0)
# Requirement already satisfied: notebook in c:\users\user\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (6.4.12)
# Requirement already satisfied: jupyter-console in c:\users\user\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (6.4.3)
# Requirement already satisfied: nbconvert in c:\users\user\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (6.4.4)
# Requirement already satisfied: qtconsole in c:\users\user\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (5.2.2)
# Requirement already satisfied: ipykernel in c:\users\user\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (6.15.2)
# Requirement already satisfied: ipywidgets in c:\users\user\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (7.6.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4>=4.8.0->django-bootstrap4->jupyter_plotly_dash) (2.3.1)
# Collecting asgiref<4,>=3.5.0
#   Downloading asgiref-3.6.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\user\anaconda3\lib\site-packages (from dash>=2.0->django-plotly-dash->jupyter_plotly_dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\user\anaconda3\lib\site-packages (from dash>=2.0->django-plotly-dash->jupyter_plotly_dash) (5.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\user\anaconda3\lib\site-packages (from dash>=2.0->django-plotly-dash->jupyter_plotly_dash) (2.0.0)
# Collecting sqlparse>=0.2.2
#   Downloading sqlparse-0.4.3-py3-none-any.whl (42 kB)
#      ---------------------------------------- 42.8/42.8 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: pytz in c:\users\user\anaconda3\lib\site-packages (from Django>=3.2->django-bootstrap4->jupyter_plotly_dash) (2022.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\user\anaconda3\lib\site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\user\anaconda3\lib\site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (2.0.1)
# Requirement already satisfied: click>=5.1 in c:\users\user\anaconda3\lib\site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (8.0.4)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\user\anaconda3\lib\site-packages (from plotly->django-plotly-dash->jupyter_plotly_dash) (8.0.1)
# Requirement already satisfied: idna>=2.0 in c:\users\user\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->jupyter_plotly_dash) (3.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (0.1.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (7.3.4)
# Requirement already satisfied: psutil in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (5.9.0)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (7.31.1)
# Requirement already satisfied: traitlets>=5.1.0 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (5.1.1)
# Requirement already satisfied: nest-asyncio in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (1.5.5)
# Requirement already satisfied: debugpy>=1.0 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (1.5.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (23.2.0)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (21.3)
# Requirement already satisfied: tornado>=6.1 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (6.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets->jupyter->jupyter_plotly_dash) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets->jupyter->jupyter_plotly_dash) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets->jupyter->jupyter_plotly_dash) (5.5.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets->jupyter->jupyter_plotly_dash) (1.0.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-console->jupyter->jupyter_plotly_dash) (3.0.20)
# Requirement already satisfied: pygments in c:\users\user\anaconda3\lib\site-packages (from jupyter-console->jupyter->jupyter_plotly_dash) (2.11.2)
# Requirement already satisfied: defusedxml in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.7.1)
# Requirement already satisfied: testpath in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.5.13)
# Requirement already satisfied: bleach in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.8.4)
# Requirement already satisfied: jupyter-core in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\user\anaconda3\lib\site-packages (from notebook->jupyter->jupyter_plotly_dash) (0.13.1)
# Requirement already satisfied: argon2-cffi in c:\users\user\anaconda3\lib\site-packages (from notebook->jupyter->jupyter_plotly_dash) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\user\anaconda3\lib\site-packages (from notebook->jupyter->jupyter_plotly_dash) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\user\anaconda3\lib\site-packages (from notebook->jupyter->jupyter_plotly_dash) (0.14.1)
# Requirement already satisfied: qtpy in c:\users\user\anaconda3\lib\site-packages (from qtconsole->jupyter->jupyter_plotly_dash) (2.2.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from click>=5.1->Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (0.4.5)
# Requirement already satisfied: backcall in c:\users\user\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->jupyter_plotly_dash) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\user\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->jupyter_plotly_dash) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->jupyter_plotly_dash) (0.18.1)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->jupyter_plotly_dash) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\user\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->jupyter_plotly_dash) (63.4.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->jupyter_plotly_dash) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-core->nbconvert->jupyter->jupyter_plotly_dash) (302)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\user\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->jupyter_plotly_dash) (4.16.0)
# Requirement already satisfied: fastjsonschema in c:\users\user\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->jupyter_plotly_dash) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->jupyter_plotly_dash) (0.2.5)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->jupyter_plotly_dash) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\user\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter->jupyter_plotly_dash) (21.2.0)
# Requirement already satisfied: webencodings in c:\users\user\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->jupyter_plotly_dash) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\user\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->jupyter_plotly_dash) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from packaging->ipykernel->jupyter->jupyter_plotly_dash) (3.0.9)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->jupyter_plotly_dash) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->jupyter_plotly_dash) (0.18.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->jupyter_plotly_dash) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->jupyter_plotly_dash) (2.21)
# Building wheels for collected packages: dpd-components
#   Building wheel for dpd-components (setup.py): started
#   Building wheel for dpd-components (setup.py): finished with status 'done'
#   Created wheel for dpd-components: filename=dpd_components-0.1.0-py3-none-any.whl size=4535 sha256=2d903dd0c77fbc650eb5576d9a2ba556fce3051c191f3e2fc774d285b6ef919e
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\df\0d\a5\30329d8fd0d3aa001680f5b3adefc6ed6d71b5e7350913ff8d
# Successfully built dpd-components
# Installing collected packages: dpd-components, sqlparse, multidict, frozenlist, dpd-static-support, async-timeout, asgiref, yarl, Django, aiosignal, django-bootstrap4, channels, aiohttp, dash-bootstrap-components, django-plotly-dash, nbserverproxy, jupyter_plotly_dash
# Successfully installed Django-3.2.18 aiohttp-3.8.4 aiosignal-1.3.1 asgiref-3.6.0 async-timeout-4.0.2 channels-4.0.0 dash-bootstrap-components-1.4.1 django-bootstrap4-22.3 django-plotly-dash-2.1.4 dpd-components-0.1.0 dpd-static-support-0.0.5 frozenlist-1.3.3 jupyter_plotly_dash-0.4.3 multidict-6.0.4 nbserverproxy-0.8.8 sqlparse-0.4.3 yarl-1.8.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from jupyter_plotly_dash import JupyterDash

import dash
import dash_core_components as dcc
from dash import html
from dash.dependencies import Input, Output

app = JupyterDash('SimpleExample')

app.layout = html.Div([
    dcc.RadioItems(
        id='dropdown-color',
        options=[{'label': c, 'value': c.lower()}
                 for c in ['Red', 'Green', 'Blue']],
        value='red'
    ),
    html.Div(id='output-color'),
    dcc.RadioItems(
        id='dropdown-size',
        options=[{'label': i, 'value': j}
                 for i, j in [('L','large'), ('M','medium'), ('S','small')]],
        value='medium'
    ),
    html.Div(id='output-size')

])

@app.callback(
    dash.dependencies.Output('output-color', 'children'),
    [dash.dependencies.Input('dropdown-color', 'value')])
def callback_color(dropdown_value):
    return "The selected color is %s." % dropdown_value

@app.callback(
    dash.dependencies.Output('output-size', 'children'),
    [dash.dependencies.Input('dropdown-color', 'value'),
     dash.dependencies.Input('dropdown-size', 'value')])
def callback_size(dropdown_color, dropdown_size):
    return "The chosen T-shirt is a %s %s one." %(dropdown_size,
                                                  dropdown_color)

app
# Out:
# <div>
#   <iframe src="/app/endpoints/5a400ca729934c68bc2c0a97844bd71f/" width=800 height=600 frameborder="0"></iframe>
#   <hr/><a href="/app/endpoints/5a400ca729934c68bc2c0a97844bd71f/" target="_new">Open in new window</a> for /app/endpoints/5a400ca729934c68bc2c0a97844bd71f/
# </div>
